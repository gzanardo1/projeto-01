# %%
print('hello world')
# Out:
# hello world

# %%
print('Giovanni Zanardo')
# Out:
# Giovanni Zanardo

# %%
def somao(a, b): 
    return a+b

# %%
print('Gio z')
# Out:
# Gio z

# %%
def soma_produto(a, b): 
    return (a+b) + (a*b)
